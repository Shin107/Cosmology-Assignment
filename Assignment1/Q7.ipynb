# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate
from scipy.integrate import quad

yrtosec=3600*24*365
Gyrtosec=10**(9)*yrtosec
H=70*3.24044*10**(-20)
omega_m=0.3; omega_lam=0.7

# %%
# CASE-1: Flat Lambda Cold Dark Matter Model

Age_Univ1,_=integrate.quad(lambda z:1/(H*(omega_m*(1+z)**(3)+omega_lam)**(1/2)),0, np.infty)

def t(zm):
    y,_=integrate.quad(lambda z:-1/(H*(omega_m*(1+z)**(3)+omega_lam)**(1/2)),0, zm)
   
    return y + Age_Univ1

print(t(0)/Gyrtosec,'Gyr',t(2)/Gyrtosec,'Gyr',t(6)/Gyrtosec,'Gyr',t(1100)/Gyrtosec,'Gyr')

Z=np.linspace(0,100,100)
T=[]

for i in range(len(Z)):
    T.append(t(Z[i])/Gyrtosec)

plt.plot(Z,T)
plt.xlabel('Redshift z')
plt.ylabel('Conformal Time [Gyr]')
plt.title(r'Flat Lambda Cold Dark Matter Model')
plt.show()
# Out:
# 46.203278836412004 Gyr 29.29548664161741 Gyr 19.284181748184054 Gyr 1.5383922286408849 Gyr

# %%
# CASE-2: Flat Dark Energy Cold Dark Matter  Model, wde=-0.7

Age_Univ2,_=integrate.quad(lambda z:1/(H*(omega_m*(1+z)**(3)+omega_lam**(0.9))**(1/2)),0, np.infty)

def t(zm):
    y1,_=integrate.quad(lambda z:-1/(H*(omega_m*(1+z)**(3)+omega_lam**(0.9))**(1/2)),0, zm)
    return y1+Age_Univ2

print(t(0)/Gyrtosec,'Gyr',t(2)/Gyrtosec,'Gyr',t(6)/Gyrtosec,'Gyr',t(1100)/Gyrtosec,'Gyr')

Z=np.linspace(0,100,100)
T=[]

for i in range(len(Z)):
    T.append(t(Z[i])/Gyrtosec)

plt.plot(Z,T)
plt.xlabel('Redshift z')
plt.ylabel('Conformal Time [Gyr]')
plt.title(r'Flat Dark Energy Cold Dark Matter  Model, $w_{DE}$=-0.7')
plt.show()
# Out:
# 46.09411112107462 Gyr 29.289317517127323 Gyr 19.283843227605374 Gyr 1.538392228633733 Gyr

# %%
# CASE-2: Flat Dark Energy Cold Dark Matter  Model, wde=-1.2

Age_Univ3,_=integrate.quad(lambda z:1/(H*(omega_m*(1+z)**(3)+omega_lam**(-0.6))**(1/2)),0, np.infty)

def t(zm):
    y1,_=integrate.quad(lambda z:-1/(H*(omega_m*(1+z)**(3)+omega_lam**(-0.6))**(1/2)),0, zm)
    return y1+Age_Univ3

print(t(0)/Gyrtosec,'Gyr',t(2)/Gyrtosec,'Gyr',t(6)/Gyrtosec,'Gyr',t(1100)/Gyrtosec,'Gyr')


Z=np.linspace(0,100,100)
T=[]

for i in range(len(Z)):
    T.append(t(Z[i])/Gyrtosec)

plt.plot(Z,T)
plt.xlabel('Redshift z')
plt.ylabel('Conformal Time [Gyr]')
plt.title(r'Flat Dark Energy Cold Dark Matter  Model, $w_{DE}$=-1.2')
plt.show()
# Out:
# 44.29513119459183 Gyr 29.167754753758743 Gyr 19.27702248672566 Gyr 1.5383922284930451 Gyr

# %%
# CASE-4: Flat Lambda Cold Dark Matter Model Omega_m= 0.8

omega_m1=0.8
Age_Univ4,_=integrate.quad(lambda z:1/(H*(omega_m1*(1+z)**(3)+omega_lam)**(1/2)),0, np.infty)

def t(zm):
    y,_=integrate.quad(lambda z:-1/(H*(omega_m1*(1+z)**(3)+omega_lam)**(1/2)),0, zm)
   
    return y + Age_Univ4

print(t(0)/Gyrtosec,'Gyr',t(2)/Gyrtosec,'Gyr',t(6)/Gyrtosec,'Gyr',t(1100)/Gyrtosec,'Gyr')

Z=np.linspace(0,100,100)
T=[]

for i in range(len(Z)):
    T.append(t(Z[i])/Gyrtosec)

plt.plot(Z,T)
plt.xlabel('Redshift z')
plt.ylabel('Conformal Time [Gyr]')
plt.title(r'Flat Lambda Cold Dark Matter Model $\Omega_m$= 0.8')
plt.show()
# Out:
# 29.77508919880202 Gyr 18.006206052242412 Gyr 11.812675930354345 Gyr 0.9420689961816824 Gyr
